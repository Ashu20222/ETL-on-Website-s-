# %% [markdown]
# # ETL ( Extraction, Transformation, Loading) part

# %% [markdown]
# # Extraction

# %%
import pandas as pd

pd.set_option('display.max_colwidth', None)


import requests
from bs4 import BeautifulSoup

url = 'https://www.imdb.com/search/title/?count=100&groups=top_1000&sort=user_rating'
response = requests.get(url)

soup = BeautifulSoup(response.text, 'html.parser')

# Find the total number of pages
num_pages = 10

# Loop through each page and extract movie information
for i in range(1, num_pages+1):
    page_url = f'{url}?page={i}'
    response = requests.get(page_url)
    soup = BeautifulSoup(response.text, 'html.parser')

# %%
# Find all the movie items on the page
movie_items = soup.find_all('div', {'class': 'lister-item-content'})
data = []
# Loop through each movie item and extract the required information
for item in movie_items:
    total = {}
    total['title'] = item.h3.a.text
    total['year'] = item.find('span', {'class': 'lister-item-year'}).text.strip('()')
    total['rating'] = item.find('div', {'class': 'inline-block ratings-imdb-rating'}).text.strip()
    total['runtime'] = item.find('span', {'class': 'runtime'}).text         
    total['description'] = item.find_all('p')[1].text.strip()
    total['genre'] = item.find('span', {'class': 'genre'}).text.strip()

    data.append(total)

# %%
data
# Out:
# [{'title': 'John Wick: Chapter 4',
#   'year': '2023',
#   'rating': '8.3',
#   'runtime': '169 min',
#   'description': 'John Wick uncovers a path to defeating The High Table. But before he can earn his freedom, Wick must face off against a new enemy with powerful alliances across the globe and forces that turn old friends into foes.',
#   'genre': 'Action, Crime, Thriller'},
#  {'title': 'Avatar: The Way of Water',
#   'year': '2022',
#   'rating': '7.7',
#   'runtime': '192 min',
#   'description': "Jake Sully lives with his newfound family formed on the extrasolar moon Pandora. Once a familiar threat returns to finish what was previously started, Jake must work with Neytiri and the army of the Na'vi race to protect their home.",
#   'genre': 'Action, Adventure, Fantasy'},
#  {'title': 'Everything Everywhere All at Once',
#   'year': '2022',
#   'rating': '7.9',
#   'runtime': '139 min',
#   'description': 'A middle-aged Chinese immigrant is swept up into an insane adventure in which she alone can save existence by exploring other universes and connecting with the lives she could have led.',
#   'genre': 'Action, Adventure, Comedy'},
#  {'title': 'The Whale',
#   'year': '2022',
#   'rating': '7.7',
#   'runtime': '117 min',
#   'description': 'A reclusive, morbidly obese English teacher attempts to reconnect with his estranged teenage daughter.',
#   'genre': 'Drama'},
#  {'title': 'Top Gun: Maverick',
#   'year': '2022',
#   'rating': '8.3',
#   'runtime': '130 min',
#   'description': "After thirty years, Maverick is still pushing the envelope as a top naval aviator, but must confront ghosts of his past when he leads TOP GUN's elite graduates on a mission that demands the ultimate sacrifice from those chosen to fly it.",
#   'genre': 'Action, Drama'},
#  {'title': 'The Banshees of Inisherin',
#   'year': '2022',
#   'rating': '7.7',
#   'runtime': '114 min',
#   'description': 'Two lifelong friends find themselves at an impasse when one abruptly ends their relationship, with alarming consequences for both of them.',
#   'genre': 'Comedy, Drama'},
#  {'title': 'Puss in Boots: The Last Wish',
#   'year': '2022',
#   'rating': '7.9',
#   'runtime': '102 min',
#   'description': 'When Puss in Boots discovers that his passion for adventure has taken its toll and he has burned through eight of his nine lives, he launches an epic journey to restore them by finding the mythical Last Wish.',
#   'genre': 'Animation, Adventure, Comedy'},
#  {'title': 'Im Westen nichts Neues',
#   'year': '2022',
#   'rating': '7.8',
#   'runtime': '148 min',
#   'description': "A young German soldier's terrifying experiences and distress on the western front during World War I.",
#   'genre': 'Action, Drama, War'},
#  {'title': 'The Godfather',
#   'year': '1972',
#   'rating': '9.2',
#   'runtime': '175 min',
#   'description': 'The aging patriarch of an organized crime dynasty in postwar New York City transfers control of his clandestine empire to his reluctant youngest son.',
#   'genre': 'Crime, Drama'},
#  {'title': 'The Shawshank Redemption',
#   'year': '1994',
#   'rating': '9.3',
#   'runtime': '142 min',
#   'description': 'Over the course of several years, two convicts form a friendship, seeking consolation and, eventually, redemption through basic compassion.',
#   'genre': 'Drama'},
#  {'title': 'The Batman',
#   'year': '2022',
#   'rating': '7.8',
#   'runtime': '176 min',
#   'description': "When a sadistic serial killer begins murdering key political figures in Gotham, Batman is forced to investigate the city's hidden corruption and question his family's involvement.",
#   'genre': 'Action, Crime, Drama'},
#  {'title': 'Interstellar',
#   'year': '2014',
#   'rating': '8.6',
#   'runtime': '169 min',
#   'description': "A team of explorers travel through a wormhole in space in an attempt to ensure humanity's survival.",
#   'genre': 'Adventure, Drama, Sci-Fi'},
#  {'title': 'Once Upon a Time in... Hollywood',
#   'year': '2019',
#   'rating': '7.6',
#   'runtime': '161 min',
#   'description': "A faded television actor and his stunt double strive to achieve fame and success in the final years of Hollywood's Golden Age in 1969 Los Angeles.",
#   'genre': 'Comedy, Drama'},
#  {'title': 'Aftersun',
#   'year': 'II) (2022',
#   'rating': '7.7',
#   'runtime': '102 min',
#   'description': "Sophie reflects on the shared joy and private melancholy of a holiday she took with her father twenty years earlier. Memories real and imagined fill the gaps between as she tries to reconcile the father she knew with the man she didn't...",
#   'genre': 'Drama'},
#  {'title': 'RRR (Rise Roar Revolt)',
#   'year': '2022',
#   'rating': '7.9',
#   'runtime': '187 min',
#   'description': 'A fictitious story about two legendary revolutionaries and their journey away from home before they started fighting for their country in the 1920s.',
#   'genre': 'Action, Drama'},
#  {'title': 'Pulp Fiction',
#   'year': '1994',
#   'rating': '8.9',
#   'runtime': '154 min',
#   'description': 'The lives of two mob hitmen, a boxer, a gangster and his wife, and a pair of diner bandits intertwine in four tales of violence and redemption.',
#   'genre': 'Crime, Drama'},
#  {'title': 'The Help',
#   'year': '2011',
#   'rating': '8.1',
#   'runtime': '146 min',
#   'description': "An aspiring author during the civil rights movement of the 1960s decides to write a book detailing the African American maids' point of view on the white families for which they work, and the hardships they go through on a daily basis.",
#   'genre': 'Drama'},
#  {'title': 'Avatar',
#   'year': '2009',
#   'rating': '7.9',
#   'runtime': '162 min',
#   'description': 'A paraplegic Marine dispatched to the moon Pandora on a unique mission becomes torn between following his orders and protecting the world he feels is his home.',
#   'genre': 'Action, Adventure, Fantasy'},
#  {'title': 'Cool Hand Luke',
#   'year': '1967',
#   'rating': '8.1',
#   'runtime': '127 min',
#   'description': 'A laid back Southern man is sentenced to two years in a rural prison, but refuses to conform.',
#   'genre': 'Crime, Drama'},
#  {'title': 'Dune: Part One',
#   'year': '2021',
#   'rating': '8.0',
#   'runtime': '155 min',
#   'description': "A noble family becomes embroiled in a war for control over the galaxy's most valuable asset while its heir becomes troubled by visions of a dark future.",
#   'genre': 'Action, Adventure, Drama'},
#  {'title': "Harry Potter and the Sorcerer's Stone",
#   'year': '2001',
#   'rating': '7.6',
#   'runtime': '152 min',
#   'description': 'An orphaned boy enrolls in a school of wizardry, where he learns the truth about himself, his family and the terrible evil that haunts the magical world.',
#   'genre': 'Adventure, Family, Fantasy'},
#  {'title': 'The Dark Knight',
#   'year': '2008',
#   'rating': '9.0',
#   'runtime': '152 min',
#   'description': 'When the menace known as the Joker wreaks havoc and chaos on the people of Gotham, Batman must accept one of the greatest psychological and physical tests of his ability to fight injustice.',
#   'genre': 'Action, Crime, Drama'},
#  {'title': 'Titanic',
#   'year': '1997',
#   'rating': '7.9',
#   'runtime': '194 min',
#   'description': 'A seventeen-year-old aristocrat falls in love with a kind but poor artist aboard the luxurious, ill-fated R.M.S. Titanic.',
#   'genre': 'Drama, Romance'},
#  {'title': 'Good Will Hunting',
#   'year': '1997',
#   'rating': '8.3',
#   'runtime': '126 min',
#   'description': 'Will Hunting, a janitor at M.I.T., has a gift for mathematics, but needs help from a psychologist to find direction in his life.',
#   'genre': 'Drama, Romance'},
#  {'title': 'The Wolf of Wall Street',
#   'year': '2013',
#   'rating': '8.2',
#   'runtime': '180 min',
#   'description': 'Based on the true story of Jordan Belfort, from his rise to a wealthy stock-broker living the high life to his fall involving crime, corruption and the federal government.',
#   'genre': 'Biography, Comedy, Crime'},
#  {'title': 'Fight Club',
#   'year': '1999',
#   'rating': '8.8',
#   'runtime': '139 min',
#   'description': 'An insomniac office worker and a devil-may-care soap maker form an underground fight club that evolves into much more.',
#   'genre': 'Drama'},
#  {'title': 'The Matrix',
#   'year': '1999',
#   'rating': '8.7',
#   'runtime': '136 min',
#   'description': 'When a beautiful stranger leads computer hacker Neo to a forbidding underworld, he discovers the shocking truth--the life he knows is the elaborate deception of an evil cyber-intelligence.',
#   'genre': 'Action, Sci-Fi'},
#  {'title': 'The Gentlemen',
#   'year': '2019',
#   'rating': '7.8',
#   'runtime': '113 min',
#   'description': 'An American expat tries to sell off his highly profitable marijuana empire in London, triggering plots, schemes, bribery and blackmail in an attempt to steal his domain out from under him.',
#   'genre': 'Action, Comedy, Crime'},
#  {'title': 'The Lord of the Rings: The Fellowship of the Ring',
#   'year': '2001',
#   'rating': '8.8',
#   'runtime': '178 min',
#   'description': 'A meek Hobbit from the Shire and eight companions set out on a journey to destroy the powerful One Ring and save Middle-earth from the Dark Lord Sauron.',
#   'genre': 'Action, Adventure, Drama'},
#  {'title': 'Joker',
#   'year': 'I) (2019',
#   'rating': '8.4',
#   'runtime': '122 min',
#   'description': "The rise of Arthur Fleck, from aspiring stand-up comedian and pariah to Gotham's clown prince and leader of the revolution.",
#   'genre': 'Crime, Drama, Thriller'},
#  {'title': 'Inception',
#   'year': '2010',
#   'rating': '8.8',
#   'runtime': '148 min',
#   'description': 'A thief who steals corporate secrets through the use of dream-sharing technology is given the inverse task of planting an idea into the mind of a C.E.O., but his tragic past may doom the project and his team to disaster.',
#   'genre': 'Action, Adventure, Sci-Fi'},
#  {'title': 'Tombstone',
#   'year': '1993',
#   'rating': '7.8',
#   'runtime': '130 min',
#   'description': "A successful lawman's plans to retire anonymously in Tombstone, Arizona are disrupted by the kind of outlaws he was famous for eliminating.",
#   'genre': 'Biography, Drama, History'},
#  {'title': 'Spider-Man: No Way Home',
#   'year': '2021',
#   'rating': '8.2',
#   'runtime': '148 min',
#   'description': "With Spider-Man's identity now revealed, Peter asks Doctor Strange for help. When a spell goes wrong, dangerous foes from other worlds start to appear, forcing Peter to discover what it truly means to be Spider-Man.",
#   'genre': 'Action, Adventure, Fantasy'},
#  {'title': 'Gisaengchung',
#   'year': '2019',
#   'rating': '8.5',
#   'runtime': '132 min',
#   'description': 'Greed and class discrimination threaten the newly formed symbiotic relationship between the wealthy Park family and the destitute Kim clan.',
#   'genre': 'Drama, Thriller'},
#  {'title': 'GoodFellas',
#   'year': '1990',
#   'rating': '8.7',
#   'runtime': '145 min',
#   'description': 'The story of Henry Hill and his life in the mob, covering his relationship with his wife Karen Hill and his mob partners Jimmy Conway and Tommy DeVito in the Italian-American crime syndicate.',
#   'genre': 'Biography, Crime, Drama'},
#  {'title': 'Forrest Gump',
#   'year': '1994',
#   'rating': '8.8',
#   'runtime': '142 min',
#   'description': 'The presidencies of Kennedy and Johnson, the Vietnam War, the Watergate scandal and other historical events unfold from the perspective of an Alabama man with an IQ of 75, whose only desire is to be reunited with his childhood sweetheart.',
#   'genre': 'Drama, Romance'},
#  {'title': 'Inglourious Basterds',
#   'year': '2009',
#   'rating': '8.3',
#   'runtime': '153 min',
#   'description': "In Nazi-occupied France during World War II, a plan to assassinate Nazi leaders by a group of Jewish U.S. soldiers coincides with a theatre owner's vengeful plans for the same.",
#   'genre': 'Adventure, Drama, War'},
#  {'title': 'Avengers: Endgame',
#   'year': '2019',
#   'rating': '8.4',
#   'runtime': '181 min',
#   'description': "After the devastating events of Avengers: Infinity War (2018), the universe is in ruins. With the help of remaining allies, the Avengers assemble once more in order to reverse Thanos' actions and restore balance to the universe.",
#   'genre': 'Action, Adventure, Drama'},
#  {'title': 'Blade Runner 2049',
#   'year': '2017',
#   'rating': '8.0',
#   'runtime': '164 min',
#   'description': "Young Blade Runner K's discovery of a long-buried secret leads him to track down former Blade Runner Rick Deckard, who's been missing for thirty years.",
#   'genre': 'Action, Drama, Mystery'},
#  {'title': 'The Goonies',
#   'year': '1985',
#   'rating': '7.7',
#   'runtime': '114 min',
#   'description': "A group of young misfits called The Goonies discover an ancient map and set out on an adventure to find a legendary pirate's long-lost treasure.",
#   'genre': 'Adventure, Comedy, Family'},
#  {'title': 'Black Swan',
#   'year': '2010',
#   'rating': '8.0',
#   'runtime': '108 min',
#   'description': 'A committed dancer struggles to maintain her sanity after winning the lead role in a production of Tchaikovsky\'s "Swan Lake".',
#   'genre': 'Drama, Thriller'},
#  {'title': 'Knives Out',
#   'year': '2019',
#   'rating': '7.9',
#   'runtime': '130 min',
#   'description': 'A detective investigates the death of the patriarch of an eccentric, combative family.',
#   'genre': 'Comedy, Crime, Drama'},
#  {'title': 'The Departed',
#   'year': '2006',
#   'rating': '8.5',
#   'runtime': '151 min',
#   'description': 'An undercover cop and a mole in the police attempt to identify each other while infiltrating an Irish gang in South Boston.',
#   'genre': 'Crime, Drama, Thriller'},
#  {'title': 'American Psycho',
#   'year': '2000',
#   'rating': '7.6',
#   'runtime': '102 min',
#   'description': 'A wealthy New York City investment banking executive, Patrick Bateman, hides his alternate psychopathic ego from his co-workers and friends as he delves deeper into his violent, hedonistic fantasies.',
#   'genre': 'Crime, Drama, Horror'},
#  {'title': 'Gladiator',
#   'year': '2000',
#   'rating': '8.5',
#   'runtime': '155 min',
#   'description': 'A former Roman General sets out to exact vengeance against the corrupt emperor who murdered his family and sent him into slavery.',
#   'genre': 'Action, Adventure, Drama'},
#  {'title': 'Whiplash',
#   'year': '2014',
#   'rating': '8.5',
#   'runtime': '106 min',
#   'description': "A promising young drummer enrolls at a cut-throat music conservatory where his dreams of greatness are mentored by an instructor who will stop at nothing to realize a student's potential.",
#   'genre': 'Drama, Music'},
#  {'title': 'Jurassic Park',
#   'year': '1993',
#   'rating': '8.2',
#   'runtime': '127 min',
#   'description': "A pragmatic paleontologist touring an almost complete theme park on an island in Central America is tasked with protecting a couple of kids after a power failure causes the park's cloned dinosaurs to run loose.",
#   'genre': 'Action, Adventure, Sci-Fi'},
#  {'title': 'The Grand Budapest Hotel',
#   'year': '2014',
#   'rating': '8.1',
#   'runtime': '99 min',
#   'description': "A writer encounters the owner of an aging high-class hotel, who tells him of his early years serving as a lobby boy in the hotel's glorious years under an exceptional concierge.",
#   'genre': 'Adventure, Comedy, Crime'},
#  {'title': "Schindler's List",
#   'year': '1993',
#   'rating': '9.0',
#   'runtime': '195 min',
#   'description': 'In German-occupied Poland during World War II, industrialist Oskar Schindler gradually becomes concerned for his Jewish workforce after witnessing their persecution by the Nazis.',
#   'genre': 'Biography, Drama, History'},
#  {'title': '12 Angry Men',
#   'year': '1957',
#   'rating': '9.0',
#   'runtime': '96 min',
#   'description': 'The jury in a New York City murder trial is frustrated by a single member whose skeptical caution forces them to more carefully consider the evidence before jumping to a hasty verdict.',
#   'genre': 'Crime, Drama'},
#  {'title': 'Requiem for a Dream',
#   'year': '2000',
#   'rating': '8.3',
#   'runtime': '102 min',
#   'description': 'The drug-induced utopias of four Coney Island people are shattered when their addictions run deep.',
#   'genre': 'Drama'},
#  {'title': 'Prisoners',
#   'year': '2013',
#   'rating': '8.1',
#   'runtime': '153 min',
#   'description': "When Keller Dover's daughter and her friend go missing, he takes matters into his own hands as the police pursue multiple leads and the pressure mounts.",
#   'genre': 'Crime, Drama, Mystery'},
#  {'title': 'Heat',
#   'year': '1995',
#   'rating': '8.3',
#   'runtime': '170 min',
#   'description': 'A group of high-end professional thieves start to feel the heat from the LAPD when they unknowingly leave a clue at their latest heist.',
#   'genre': 'Action, Crime, Drama'},
#  {'title': 'Pride & Prejudice',
#   'year': '2005',
#   'rating': '7.8',
#   'runtime': '129 min',
#   'description': 'Sparks fly when spirited Elizabeth Bennet meets single, rich, and proud Mr. Darcy. But Mr. Darcy reluctantly finds himself falling in love with a woman beneath his class. Can each overcome their own pride and prejudice?',
#   'genre': 'Drama, Romance'},
#  {'title': 'Rocky',
#   'year': '1976',
#   'rating': '8.1',
#   'runtime': '120 min',
#   'description': 'A small-time Philadelphia boxer gets a supremely rare chance to fight the world heavyweight champion in a bout in which he strives to go the distance for his self-respect.',
#   'genre': 'Drama, Sport'},
#  {'title': 'Detachment',
#   'year': '2011',
#   'rating': '7.7',
#   'runtime': '98 min',
#   'description': 'A substitute teacher who drifts from classroom to classroom finds a connection to the students and teachers during his latest assignment.',
#   'genre': 'Drama'},
#  {'title': 'Taxi Driver',
#   'year': '1976',
#   'rating': '8.2',
#   'runtime': '114 min',
#   'description': 'A mentally unstable veteran works as a nighttime taxi driver in New York City, where the perceived decadence and sleaze fuels his urge for violent action.',
#   'genre': 'Crime, Drama'},
#  {'title': 'Se7en',
#   'year': '1995',
#   'rating': '8.6',
#   'runtime': '127 min',
#   'description': 'Two detectives, a rookie and a veteran, hunt a serial killer who uses the seven deadly sins as his motives.',
#   'genre': 'Crime, Drama, Mystery'},
#  {'title': 'The Prestige',
#   'year': '2006',
#   'rating': '8.5',
#   'runtime': '130 min',
#   'description': 'After a tragic accident, two stage magicians in 1890s London engage in a battle to create the ultimate illusion while sacrificing everything they have to outwit each other.',
#   'genre': 'Drama, Mystery, Sci-Fi'},
#  {'title': 'The Silence of the Lambs',
#   'year': '1991',
#   'rating': '8.6',
#   'runtime': '118 min',
#   'description': 'A young F.B.I. cadet must receive the help of an incarcerated and manipulative cannibal killer to help catch another serial killer, a madman who skins his victims.',
#   'genre': 'Crime, Drama, Thriller'},
#  {'title': 'Mad Max: Fury Road',
#   'year': '2015',
#   'rating': '8.1',
#   'runtime': '120 min',
#   'description': 'In a post-apocalyptic wasteland, a woman rebels against a tyrannical ruler in search for her homeland with the aid of a group of female prisoners, a psychotic worshiper and a drifter named Max.',
#   'genre': 'Action, Adventure, Sci-Fi'},
#  {'title': 'Django Unchained',
#   'year': '2012',
#   'rating': '8.4',
#   'runtime': '165 min',
#   'description': 'With the help of a German bounty-hunter, a freed slave sets out to rescue his wife from a brutal plantation owner in Mississippi.',
#   'genre': 'Drama, Western'},
#  {'title': 'The Fugitive',
#   'year': '1993',
#   'rating': '7.8',
#   'runtime': '130 min',
#   'description': 'Dr. Richard Kimble, unjustly accused of murdering his wife, must find the real killer while being the target of a nationwide manhunt led by a seasoned U.S. Marshal.',
#   'genre': 'Action, Crime, Drama'},
#  {'title': "One Flew Over the Cuckoo's Nest",
#   'year': '1975',
#   'rating': '8.7',
#   'runtime': '133 min',
#   'description': 'In the Fall of 1963, a Korean War veteran and criminal pleads insanity and is admitted to a mental institution, where he rallies up the scared patients against the tyrannical nurse.',
#   'genre': 'Drama'},
#  {'title': 'Get Out',
#   'year': 'I) (2017',
#   'rating': '7.7',
#   'runtime': '104 min',
#   'description': "A young African-American visits his White girlfriend's parents for the weekend, where his simmering uneasiness about their reception of him eventually reaches a boiling point.",
#   'genre': 'Horror, Mystery, Thriller'},
#  {'title': 'Gone Girl',
#   'year': '2014',
#   'rating': '8.1',
#   'runtime': '149 min',
#   'description': "With his wife's disappearance having become the focus of an intense media circus, a man sees the spotlight turned on him when it's suspected that he may not be innocent.",
#   'genre': 'Drama, Mystery, Thriller'},
#  {'title': 'American Beauty',
#   'year': '1999',
#   'rating': '8.4',
#   'runtime': '122 min',
#   'description': "A sexually frustrated suburban father has a mid-life crisis after becoming infatuated with his daughter's best friend.",
#   'genre': 'Drama'},
#  {'title': 'The Lord of the Rings: The Return of the King',
#   'year': '2003',
#   'rating': '9.0',
#   'runtime': '201 min',
#   'description': "Gandalf and Aragorn lead the World of Men against Sauron's army to draw his gaze from Frodo and Sam as they approach Mount Doom with the One Ring.",
#   'genre': 'Action, Adventure, Drama'},
#  {'title': 'The Hangover',
#   'year': '2009',
#   'rating': '7.7',
#   'runtime': '100 min',
#   'description': 'Three buddies wake up from a bachelor party in Las Vegas, with no memory of the previous night and the bachelor missing. They make their way around the city in order to find their friend before his wedding.',
#   'genre': 'Comedy'},
#  {'title': 'The Green Mile',
#   'year': '1999',
#   'rating': '8.6',
#   'runtime': '189 min',
#   'description': 'The lives of guards on Death Row are affected by one of their charges: a black man accused of child murder and rape, yet who has a mysterious gift.',
#   'genre': 'Crime, Drama, Fantasy'},
#  {'title': 'The Sixth Sense',
#   'year': '1999',
#   'rating': '8.2',
#   'runtime': '107 min',
#   'description': 'A frightened, withdrawn Philadelphia boy who communicates with spirits seeks the help of a disheartened child psychologist.',
#   'genre': 'Drama, Mystery, Thriller'},
#  {'title': 'Alien',
#   'year': '1979',
#   'rating': '8.5',
#   'runtime': '117 min',
#   'description': 'The crew of a commercial spacecraft encounter a deadly lifeform after investigating an unknown transmission.',
#   'genre': 'Horror, Sci-Fi'},
#  {'title': 'Star Wars',
#   'year': '1977',
#   'rating': '8.6',
#   'runtime': '121 min',
#   'description': "Luke Skywalker joins forces with a Jedi Knight, a cocky pilot, a Wookiee and two droids to save the galaxy from the Empire's world-destroying battle station, while also attempting to rescue Princess Leia from the mysterious Darth Vader.",
#   'genre': 'Action, Adventure, Fantasy'},
#  {'title': 'Sicario',
#   'year': '2015',
#   'rating': '7.6',
#   'runtime': '121 min',
#   'description': 'An idealistic FBI agent is enlisted by a government task force to aid in the escalating war against drugs at the border area between the U.S. and Mexico.',
#   'genre': 'Action, Crime, Drama'},
#  {'title': 'Eternal Sunshine of the Spotless Mind',
#   'year': '2004',
#   'rating': '8.3',
#   'runtime': '108 min',
#   'description': 'When their relationship turns sour, a couple undergoes a medical procedure to have each other erased from their memories for ever.',
#   'genre': 'Drama, Romance, Sci-Fi'},
#  {'title': 'Guardians of the Galaxy',
#   'year': '2014',
#   'rating': '8.0',
#   'runtime': '121 min',
#   'description': 'A group of intergalactic criminals must pull together to stop a fanatical warrior with plans to purge the universe.',
#   'genre': 'Action, Adventure, Comedy'},
#  {'title': 'The Godfather Part II',
#   'year': '1974',
#   'rating': '9.0',
#   'runtime': '202 min',
#   'description': 'The early life and career of Vito Corleone in 1920s New York City is portrayed, while his son, Michael, expands and tightens his grip on the family crime syndicate.',
#   'genre': 'Crime, Drama'},
#  {'title': 'Léon',
#   'year': '1994',
#   'rating': '8.5',
#   'runtime': '110 min',
#   'description': "12-year-old Mathilda is reluctantly taken in by Léon, a professional assassin, after her family is murdered. An unusual relationship forms as she becomes his protégée and learns the assassin's trade.",
#   'genre': 'Action, Crime, Drama'},
#  {'title': 'Raiders of the Lost Ark',
#   'year': '1981',
#   'rating': '8.4',
#   'runtime': '115 min',
#   'description': 'In 1936, archaeologist and adventurer Indiana Jones is hired by the U.S. government to find the Ark of the Covenant before the Nazis can obtain its awesome powers.',
#   'genre': 'Action, Adventure'},
#  {'title': 'Terminator 2: Judgment Day',
#   'year': '1991',
#   'rating': '8.6',
#   'runtime': '137 min',
#   'description': 'A cyborg, identical to the one who failed to kill Sarah Connor, must now protect her 10-year old son John from an even more advanced and powerful cyborg.',
#   'genre': 'Action, Sci-Fi'},
#  {'title': 'Back to the Future',
#   'year': '1985',
#   'rating': '8.5',
#   'runtime': '116 min',
#   'description': 'Marty McFly, a 17-year-old high school student, is accidentally sent 30 years into the past in a time-traveling DeLorean invented by his close friend, the maverick scientist Doc Brown.',
#   'genre': 'Adventure, Comedy, Sci-Fi'},
#  {'title': 'Rogue One',
#   'year': '2016',
#   'rating': '7.8',
#   'runtime': '133 min',
#   'description': "In a time of conflict, a group of unlikely heroes band together on a mission to steal the plans to the Death Star, the Empire's ultimate weapon of destruction.",
#   'genre': 'Action, Adventure, Sci-Fi'},
#  {'title': 'Psycho',
#   'year': '1960',
#   'rating': '8.5',
#   'runtime': '109 min',
#   'description': "A Phoenix secretary embezzles $40,000 from her employer's client, goes on the run and checks into a remote motel run by a young man under the domination of his mother.",
#   'genre': 'Horror, Mystery, Thriller'},
#  {'title': 'The Shining',
#   'year': '1980',
#   'rating': '8.4',
#   'runtime': '146 min',
#   'description': 'A family heads to an isolated hotel for the winter where a sinister presence influences the father into violence, while his psychic son sees horrific forebodings from both past and future.',
#   'genre': 'Drama, Horror'},
#  {'title': 'Shutter Island',
#   'year': '2010',
#   'rating': '8.2',
#   'runtime': '138 min',
#   'description': 'In 1954, a U.S. Marshal investigates the disappearance of a murderer who escaped from a hospital for the criminally insane.',
#   'genre': 'Mystery, Thriller'},
#  {'title': 'No Country for Old Men',
#   'year': '2007',
#   'rating': '8.2',
#   'runtime': '122 min',
#   'description': 'Violence and mayhem ensue after a hunter stumbles upon a drug deal gone wrong and more than two million dollars in cash near the Rio Grande.',
#   'genre': 'Crime, Drama, Thriller'},
#  {'title': 'The Breakfast Club',
#   'year': '1985',
#   'rating': '7.8',
#   'runtime': '97 min',
#   'description': 'Five high school students meet in Saturday detention and discover how they have a lot more in common than they thought.',
#   'genre': 'Comedy, Drama'},
#  {'title': 'Hidden Figures',
#   'year': '2016',
#   'rating': '7.8',
#   'runtime': '127 min',
#   'description': 'The story of a team of female African-American mathematicians who served a vital role in NASA during the early years of the U.S. space program.',
#   'genre': 'Biography, Drama, History'},
#  {'title': 'Pirates of the Caribbean: The Curse of the Black Pearl',
#   'year': '2003',
#   'rating': '8.1',
#   'runtime': '143 min',
#   'description': 'Blacksmith Will Turner teams up with eccentric pirate "Captain" Jack Sparrow to save his love, the governor\'s daughter, from Jack\'s former pirate allies, who are now undead.',
#   'genre': 'Action, Adventure, Fantasy'},
#  {'title': 'Superbad',
#   'year': '2007',
#   'rating': '7.6',
#   'runtime': '113 min',
#   'description': 'Two co-dependent high school seniors are forced to deal with separation anxiety after their plan to stage a booze-soaked party goes awry.',
#   'genre': 'Comedy'},
#  {'title': 'Stand by Me',
#   'year': '1986',
#   'rating': '8.1',
#   'runtime': '89 min',
#   'description': 'After the death of one of his friends, a writer recounts a childhood journey with his friends to find the body of a missing boy.',
#   'genre': 'Adventure, Drama'},
#  {'title': 'Apocalypse Now',
#   'year': '1979',
#   'rating': '8.5',
#   'runtime': '147 min',
#   'description': 'A U.S. Army officer serving in Vietnam is tasked with assassinating a renegade Special Forces Colonel who sees himself as a god.',
#   'genre': 'Drama, Mystery, War'},
#  {'title': 'The Princess Bride',
#   'year': '1987',
#   'rating': '8.0',
#   'runtime': '98 min',
#   'description': "A bedridden boy's grandfather reads him the story of a farmboy-turned-pirate who encounters numerous obstacles, enemies and allies in his quest to be reunited with his true love.",
#   'genre': 'Adventure, Comedy, Family'},
#  {'title': 'Green Book',
#   'year': '2018',
#   'rating': '8.2',
#   'runtime': '130 min',
#   'description': 'A working-class Italian-American bouncer becomes the driver for an African-American classical pianist on a tour of venues through the 1960s American South.',
#   'genre': 'Biography, Comedy, Drama'},
#  {'title': 'Little Women',
#   'year': '2019',
#   'rating': '7.8',
#   'runtime': '135 min',
#   'description': 'Jo March reflects back and forth on her life, telling the beloved story of the March sisters - four young women, each determined to live life on her own terms.',
#   'genre': 'Drama, Romance'},
#  {'title': 'The Big Short',
#   'year': '2015',
#   'rating': '7.8',
#   'runtime': '130 min',
#   'description': 'In 2006-2007 a group of investors bet against the United States mortgage market. In their research, they discover how flawed and corrupt the market is.',
#   'genre': 'Biography, Comedy, Drama'},
#  {'title': 'There Will Be Blood',
#   'year': '2007',
#   'rating': '8.2',
#   'runtime': '158 min',
#   'description': 'A story of family, religion, hatred, oil and madness, focusing on a turn-of-the-century prospector in the early days of the business.',
#   'genre': 'Drama'},
#  {'title': "Zack Snyder's Justice League",
#   'year': '2021',
#   'rating': '8.0',
#   'runtime': '242 min',
#   'description': "Determined to ensure that Superman's ultimate sacrifice wasn't in vain, Bruce Wayne recruits a team of metahumans to protect the world from an approaching threat of catastrophic proportions.",
#   'genre': 'Action, Adventure, Fantasy'},
#  {'title': 'A Clockwork Orange',
#   'year': '1971',
#   'rating': '8.3',
#   'runtime': '136 min',
#   'description': "In the future, a sadistic gang leader is imprisoned and volunteers for a conduct-aversion experiment, but it doesn't go as planned.",
#   'genre': 'Crime, Sci-Fi'},
#  {'title': 'The Martian',
#   'year': '2015',
#   'rating': '8.0',
#   'runtime': '144 min',
#   'description': 'An astronaut becomes stranded on Mars after his team assume him dead, and must rely on his ingenuity to find a way to signal to Earth that he is alive and can survive until a potential rescue.',
#   'genre': 'Adventure, Drama, Sci-Fi'}]

# %% [markdown]
# ## Transformation

# %%
imdb = pd.DataFrame(data)
imdb
# Out:
#                                 title  year rating  runtime  \
# 0                John Wick: Chapter 4  2023    8.3  169 min
# 1            Avatar: The Way of Water  2022    7.7  192 min
# 2   Everything Everywhere All at Once  2022    7.9  139 min
# 3                           The Whale  2022    7.7  117 min
# 4                   Top Gun: Maverick  2022    8.3  130 min
# ..                                ...   ...    ...      ...
# 95                      The Big Short  2015    7.8  130 min
# 96                There Will Be Blood  2007    8.2  158 min
# 97       Zack Snyder's Justice League  2021    8.0  242 min
# 98                 A Clockwork Orange  1971    8.3  136 min
# 99                        The Martian  2015    8.0  144 min
#
#                                                                                                                                                                                                                                       description  \
# 0                          John Wick uncovers a path to defeating The High Table. But before he can earn his freedom, Wick must face off against a new enemy with powerful alliances across the globe and forces that turn old friends into foes.
# 1        Jake Sully lives with his newfound family formed on the extrasolar moon Pandora. Once a familiar threat returns to finish what was previously started, Jake must work with Neytiri and the army of the Na'vi race to protect their home.
# 2                                                       A middle-aged Chinese immigrant is swept up into an insane adventure in which she alone can save existence by exploring other universes and connecting with the lives she could have led.
# 3                                                                                                                                          A reclusive, morbidly obese English teacher attempts to reconnect with his estranged teenage daughter.
# 4   After thirty years, Maverick is still pushing the envelope as a top naval aviator, but must confront ghosts of his past when he leads TOP GUN's elite graduates on a mission that demands the ultimate sacrifice from those chosen to fly it.
# ..                                                                                                                                                                                                                                            ...
# 95                                                                                        In 2006-2007 a group of investors bet against the United States mortgage market. In their research, they discover how flawed and corrupt the market is.
# 96                                                                                                          A story of family, religion, hatred, oil and madness, focusing on a turn-of-the-century prospector in the early days of the business.
# 97                                                 Determined to ensure that Superman's ultimate sacrifice wasn't in vain, Bruce Wayne recruits a team of metahumans to protect the world from an approaching threat of catastrophic proportions.
# 98                                                                                                            In the future, a sadistic gang leader is imprisoned and volunteers for a conduct-aversion experiment, but it doesn't go as planned.
# 99                                               An astronaut becomes stranded on Mars after his team assume him dead, and must rely on his ingenuity to find a way to signal to Earth that he is alive and can survive until a potential rescue.
#
#                          genre
# 0      Action, Crime, Thriller
# 1   Action, Adventure, Fantasy
# 2    Action, Adventure, Comedy
# 3                        Drama
# 4                Action, Drama
# ..                         ...
# 95    Biography, Comedy, Drama
# 96                       Drama
# 97  Action, Adventure, Fantasy
# 98               Crime, Sci-Fi
# 99    Adventure, Drama, Sci-Fi
#
# [100 rows x 6 columns]

# %%
imdb['year'] = imdb['year'].str.replace('[^a-zA-Z0-9\w\s]', '', regex=True)

# %%
import re

imdb['year'] = imdb['year'].apply(lambda x: re.findall('\d+', str(x))[0]).astype(int)

# %%
imdb['runtime_in_min'] = imdb['runtime'].apply(lambda x: re.findall('\d+', str(x))[0]).astype(float)

# %%
imdb['rating'] = imdb['rating'].astype(float)

# %%
imdb['year'] = imdb['year'].astype(int)

# %%
imdb['rating'] = imdb['rating'].astype(float)

# %%
unique_values = imdb['year'].unique()
unique_values
# Out:
# array([2023, 2022, 1972, 1994, 2014, 2019, 2011, 2009, 1967, 2021, 2001,
#        2008, 1997, 2013, 1999, 2010, 1993, 1990, 2017, 1985, 2006, 2000,
#        1957, 1995, 2005, 1976, 1991, 2015, 2012, 1975, 2003, 1979, 1977,
#        2004, 1974, 1981, 2016, 1960, 1980, 2007, 1986, 1987, 2018, 1971])

# %%
imdb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           100 non-null    object
#  1   year            100 non-null    int32
#  2   rating          100 non-null    float64
#  3   runtime         100 non-null    object
#  4   description     100 non-null    object
#  5   genre           100 non-null    object
#  6   runtime_in_min  100 non-null    float64
# dtypes: float64(2), int32(1), object(4)
# memory usage: 5.2+ KB

# %%
imdb.head()
# Out:
#                                title  year  rating  runtime  \
# 0               John Wick: Chapter 4  2023     8.3  169 min
# 1           Avatar: The Way of Water  2022     7.7  192 min
# 2  Everything Everywhere All at Once  2022     7.9  139 min
# 3                          The Whale  2022     7.7  117 min
# 4                  Top Gun: Maverick  2022     8.3  130 min
#
#                                                                                                                                                                                                                                      description  \
# 0                         John Wick uncovers a path to defeating The High Table. But before he can earn his freedom, Wick must face off against a new enemy with powerful alliances across the globe and forces that turn old friends into foes.
# 1       Jake Sully lives with his newfound family formed on the extrasolar moon Pandora. Once a familiar threat returns to finish what was previously started, Jake must work with Neytiri and the army of the Na'vi race to protect their home.
# 2                                                      A middle-aged Chinese immigrant is swept up into an insane adventure in which she alone can save existence by exploring other universes and connecting with the lives she could have led.
# 3                                                                                                                                         A reclusive, morbidly obese English teacher attempts to reconnect with his estranged teenage daughter.
# 4  After thirty years, Maverick is still pushing the envelope as a top naval aviator, but must confront ghosts of his past when he leads TOP GUN's elite graduates on a mission that demands the ultimate sacrifice from those chosen to fly it.
#
#                         genre  runtime_in_min
# 0     Action, Crime, Thriller           169.0
# 1  Action, Adventure, Fantasy           192.0
# 2   Action, Adventure, Comedy           139.0
# 3                       Drama           117.0
# 4               Action, Drama           130.0

# %%
imdb = imdb.drop('runtime', axis=1)
imdb.head()
# Out:
#                                title  year  rating  \
# 0               John Wick: Chapter 4  2023     8.3
# 1           Avatar: The Way of Water  2022     7.7
# 2  Everything Everywhere All at Once  2022     7.9
# 3                          The Whale  2022     7.7
# 4                  Top Gun: Maverick  2022     8.3
#
#                                                                                                                                                                                                                                      description  \
# 0                         John Wick uncovers a path to defeating The High Table. But before he can earn his freedom, Wick must face off against a new enemy with powerful alliances across the globe and forces that turn old friends into foes.
# 1       Jake Sully lives with his newfound family formed on the extrasolar moon Pandora. Once a familiar threat returns to finish what was previously started, Jake must work with Neytiri and the army of the Na'vi race to protect their home.
# 2                                                      A middle-aged Chinese immigrant is swept up into an insane adventure in which she alone can save existence by exploring other universes and connecting with the lives she could have led.
# 3                                                                                                                                         A reclusive, morbidly obese English teacher attempts to reconnect with his estranged teenage daughter.
# 4  After thirty years, Maverick is still pushing the envelope as a top naval aviator, but must confront ghosts of his past when he leads TOP GUN's elite graduates on a mission that demands the ultimate sacrifice from those chosen to fly it.
#
#                         genre  runtime_in_min
# 0     Action, Crime, Thriller           169.0
# 1  Action, Adventure, Fantasy           192.0
# 2   Action, Adventure, Comedy           139.0
# 3                       Drama           117.0
# 4               Action, Drama           130.0

# %%
imdb
# Out:
#                                 title  year  rating  \
# 0                John Wick: Chapter 4  2023     8.3
# 1            Avatar: The Way of Water  2022     7.7
# 2   Everything Everywhere All at Once  2022     7.9
# 3                           The Whale  2022     7.7
# 4                   Top Gun: Maverick  2022     8.3
# ..                                ...   ...     ...
# 95                      The Big Short  2015     7.8
# 96                There Will Be Blood  2007     8.2
# 97       Zack Snyder's Justice League  2021     8.0
# 98                 A Clockwork Orange  1971     8.3
# 99                        The Martian  2015     8.0
#
#                                                                                                                                                                                                                                       description  \
# 0                          John Wick uncovers a path to defeating The High Table. But before he can earn his freedom, Wick must face off against a new enemy with powerful alliances across the globe and forces that turn old friends into foes.
# 1        Jake Sully lives with his newfound family formed on the extrasolar moon Pandora. Once a familiar threat returns to finish what was previously started, Jake must work with Neytiri and the army of the Na'vi race to protect their home.
# 2                                                       A middle-aged Chinese immigrant is swept up into an insane adventure in which she alone can save existence by exploring other universes and connecting with the lives she could have led.
# 3                                                                                                                                          A reclusive, morbidly obese English teacher attempts to reconnect with his estranged teenage daughter.
# 4   After thirty years, Maverick is still pushing the envelope as a top naval aviator, but must confront ghosts of his past when he leads TOP GUN's elite graduates on a mission that demands the ultimate sacrifice from those chosen to fly it.
# ..                                                                                                                                                                                                                                            ...
# 95                                                                                        In 2006-2007 a group of investors bet against the United States mortgage market. In their research, they discover how flawed and corrupt the market is.
# 96                                                                                                          A story of family, religion, hatred, oil and madness, focusing on a turn-of-the-century prospector in the early days of the business.
# 97                                                 Determined to ensure that Superman's ultimate sacrifice wasn't in vain, Bruce Wayne recruits a team of metahumans to protect the world from an approaching threat of catastrophic proportions.
# 98                                                                                                            In the future, a sadistic gang leader is imprisoned and volunteers for a conduct-aversion experiment, but it doesn't go as planned.
# 99                                               An astronaut becomes stranded on Mars after his team assume him dead, and must rely on his ingenuity to find a way to signal to Earth that he is alive and can survive until a potential rescue.
#
#                          genre  runtime_in_min
# 0      Action, Crime, Thriller           169.0
# 1   Action, Adventure, Fantasy           192.0
# 2    Action, Adventure, Comedy           139.0
# 3                        Drama           117.0
# 4                Action, Drama           130.0
# ..                         ...             ...
# 95    Biography, Comedy, Drama           130.0
# 96                       Drama           158.0
# 97  Action, Adventure, Fantasy           242.0
# 98               Crime, Sci-Fi           136.0
# 99    Adventure, Drama, Sci-Fi           144.0
#
# [100 rows x 6 columns]

# %% [markdown]
# # Loading

# %%
IMDB_descriptive_data = imdb

# %%
output_file = r'C:\Users\ashut\Downloads\IMDB_descriptive_data.csv'

# write the dataframe to a CSV file at the desired location
IMDB_descriptive_data.to_csv(output_file, index=False)

# %%
file_path = r'C:\Users\ashut\Downloads\IMDB_descriptive_data.json'
IMDB_descriptive_data.to_json(file_path, orient='records')
