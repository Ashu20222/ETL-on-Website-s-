# %% [markdown]
# # ETL ( Extraction, Transformation, Loading) part

# %% [markdown]
# # Extraction

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

base_url = 'https://www.imdb.com/search/title/?count=100&groups=top_1000&sort=user_rating'

num_pages = 11

movies = []

for i in range(1, num_pages+1):
    url = base_url + f'&start={i*100}'
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    movie_containers = soup.find_all('div', class_='lister-item mode-advanced')
    
    for movie in movie_containers:
        title = movie.h3.a.text
        year = movie.h3.find('span', class_='lister-item-year').text.strip('()')
        rating = movie.strong.text
        runtime = movie.find('span', class_='runtime').text
        genre = movie.find('span', class_='genre').text.strip()
        director = movie.find_all('p')[2].a.text
        stars = [star.text for star in movie.find_all('p')[2].find_all('a')[1:]]
        gross = movie.find_all('span', attrs={'name': 'nv'})[0].text
        
        movie_data = {
            'title': title,
            'year': year,
            'rating': rating,
            'runtime': runtime,
            'genre': genre,
            'director': director,
            'stars': stars,
            'gross': gross
        }
        
        movies.append(movie_data)
    
    # pause the loop for a few seconds to avoid overwhelming the website with requests
    time.sleep(2)

# %% [markdown]
# # Transformation

# %%
# create a pandas dataframe from the list of movies
imdb_dataset = pd.DataFrame(movies)

# %%
imdb_dataset.head()
# Out:
#                    title  year rating  runtime                      genre  \
# 0  2001: A Space Odyssey  1968    8.3  149 min          Adventure, Sci-Fi
# 1         Reservoir Dogs  1992    8.3   99 min            Crime, Thriller
# 2               Scarface  1983    8.3  170 min               Crime, Drama
# 3      Full Metal Jacket  1987    8.3  116 min                 Drama, War
# 4               Hamilton  2020    8.3  160 min  Biography, Drama, History
#
#             director                                              stars  \
# 0    Stanley Kubrick  [Keir Dullea, Gary Lockwood, William Sylvester...
# 1  Quentin Tarantino  [Harvey Keitel, Tim Roth, Michael Madsen, Chri...
# 2     Brian De Palma  [Al Pacino, Michelle Pfeiffer, Steven Bauer, M...
# 3    Stanley Kubrick  [Matthew Modine, R. Lee Ermey, Vincent D'Onofr...
# 4        Thomas Kail  [Lin-Manuel Miranda, Phillipa Soo, Leslie Odom...
#
#        gross
# 0    680,413
# 1  1,035,752
# 2    858,124
# 3    753,636
# 4     99,582

# %%
imdb_dataset['year'] = imdb_dataset['year'].str.replace('[^a-zA-Z0-9\w\s]', '', regex=True)

# %%
import re
imdb_dataset['year'] = imdb_dataset['year'].apply(lambda x: re.findall('\d+', str(x))[0]).astype(int)

# %%
imdb_dataset['runtime_in_min'] = imdb_dataset['runtime'].apply(lambda x: re.findall('\d+', str(x))[0]).astype(float)

# %%
imdb_dataset['rating'] = imdb_dataset['rating'].astype(float)

# %%
imdb_dataset['gross'] = pd.to_numeric(imdb_dataset['gross'].str.replace(',', ''), errors='coerce').astype(int)

# %%
imdb_dataset = imdb_dataset.drop('runtime', axis=1)

# %%
imdb_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 901 entries, 0 to 900
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           901 non-null    object
#  1   year            901 non-null    int32
#  2   rating          901 non-null    float64
#  3   genre           901 non-null    object
#  4   director        901 non-null    object
#  5   stars           901 non-null    object
#  6   gross           901 non-null    int32
#  7   runtime_in_min  901 non-null    float64
# dtypes: float64(2), int32(2), object(4)
# memory usage: 49.4+ KB

# %%
imdb_dataset
# Out:
#                      title  year  rating                      genre  \
# 0    2001: A Space Odyssey  1968     8.3          Adventure, Sci-Fi
# 1           Reservoir Dogs  1992     8.3            Crime, Thriller
# 2                 Scarface  1983     8.3               Crime, Drama
# 3        Full Metal Jacket  1987     8.3                 Drama, War
# 4                 Hamilton  2020     8.3  Biography, Drama, History
# ..                     ...   ...     ...                        ...
# 896   Les yeux sans visage  1960     7.6              Drama, Horror
# 897                  Shine  1996     7.6    Biography, Drama, Music
# 898      The Invisible Man  1933     7.6             Horror, Sci-Fi
# 899         The Odd Couple  1968     7.6                     Comedy
# 900              Celda 211  2009     7.6   Action, Adventure, Crime
#
#               director                                              stars  \
# 0      Stanley Kubrick  [Keir Dullea, Gary Lockwood, William Sylvester...
# 1    Quentin Tarantino  [Harvey Keitel, Tim Roth, Michael Madsen, Chri...
# 2       Brian De Palma  [Al Pacino, Michelle Pfeiffer, Steven Bauer, M...
# 3      Stanley Kubrick  [Matthew Modine, R. Lee Ermey, Vincent D'Onofr...
# 4          Thomas Kail  [Lin-Manuel Miranda, Phillipa Soo, Leslie Odom...
# ..                 ...                                                ...
# 896     Georges Franju  [Pierre Brasseur, Alida Valli, Juliette Maynie...
# 897        Scott Hicks  [Geoffrey Rush, Armin Mueller-Stahl, Justin Br...
# 898        James Whale  [Claude Rains, Gloria Stuart, William Harrigan...
# 899          Gene Saks  [Jack Lemmon, Walter Matthau, John Fiedler, He...
# 900      Daniel Monzón  [Luis Tosar, Alberto Ammann, Antonio Resines, ...
#
#        gross  runtime_in_min
# 0     680413           149.0
# 1    1035752            99.0
# 2     858124           170.0
# 3     753636           116.0
# 4      99582           160.0
# ..       ...             ...
# 896    32977            90.0
# 897    55114           105.0
# 898    37154            71.0
# 899    35987           105.0
# 900    68907           113.0
#
# [901 rows x 8 columns]

# %% [markdown]
# # Loading

# %%
file_path = r'C:\Users\ashut\Downloads\imdb_dataset.csv'

# write the dataframe to a CSV file at the desired location
imdb_dataset.to_csv(file_path, index=False)

# %%
file_path = r'C:\Users\ashut\Downloads\imdb_dataset.json'
imdb_dataset.to_json(file_path, orient='records')
